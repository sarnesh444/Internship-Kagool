# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_excel("Sales by country.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-97cf942837f7> in <module>()
# ----> 1 df=pd.read_excel("Sales by country.xlsx")
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# ...

# %%
df.head()
# Out:
#        Country        Sales
# 0  Afghanistan  21673.32000
# 1      Albania   3888.12000
# 2      Algeria  36091.59000
# 3       Angola  25554.00000
# 4    Argentina  57511.78328

# %%
df=df.sort_values(by="Sales",ascending=False)

# %%
df.dtypes
# Out:
# Country     object
# Sales      float64
# dtype: object

# %%
df.head()
# Out:
#            Country         Sales
# 156  United States  2.297201e+06
# 6        Australia  9.252359e+05
# 50          France  8.589311e+05
# 30           China  7.005620e+05
# 54         Germany  6.281362e+05

# %%
df["Sales"]=df["Sales"].astype("int")

# %%
df.head(6)
# Out:
#            Country    Sales
# 156  United States  2297200
# 6        Australia   925235
# 50          France   858931
# 30           China   700562
# 54         Germany   628136
# 94          Mexico   621552

# %%
sns.catplot("Country","Sales",data=df)

# %%
sns.catplot("Country","Sales",data=df.query("Sales>621552"))

# %% [markdown]
# #From here starts the new work

# %%
df=pd.read_excel("/content/Global Superstore 2018.xlsx",sheet_name="Orders")

# %%
df.head()
# Out:
#    Row ID                Order ID  ... Shipping Cost Order Priority
# 0   24599  IN-2017-CA120551-42816  ...         39.66         Medium
# 1   29465  ID-2015-BD116051-42248  ...         18.72         Medium
# 2   24598  IN-2017-CA120551-42816  ...         14.10         Medium
# 3   24597  IN-2017-CA120551-42816  ...         11.01         Medium
# 4   29464  ID-2015-BD116051-42248  ...          5.72         Medium
#
# [5 rows x 24 columns]

# %%
df_copy1=df.copy()
df_copy2=df.copy()
df_copy3=df.copy()

# %%
df_copy1=df_copy1[df_copy1.Country=="United States"] #selecting the rows having United States as a country

# %%
sns.set_style("ticks")

# %%
df_new_copy1=df_copy1.copy()

# %%
df_new_copy1=df_copy2[df_copy2.Country=="Germany"]

# %%
vertical_stack = pd.concat([df_new_copy1,df_copy1], axis=0) #concatination via rows

# %%
vertical_stack.info() #12057=9994+2063
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12057 entries, 15494 to 50546
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          12057 non-null  int64
#  1   Order ID        12057 non-null  object
#  2   Order Date      12057 non-null  datetime64[ns]
#  3   Ship Date       12057 non-null  datetime64[ns]
#  4   Ship Mode       12057 non-null  object
#  5   Customer ID     12057 non-null  object
#  6   Customer Name   12057 non-null  object
#  7   Segment         12057 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            12057 non-null  object
#  10  State           12057 non-null  object
#  11  Country         12057 non-null  object
#  12  Region          12057 non-null  object
#  13  Market          12057 non-null  object
#  14  Product ID      12057 non-null  object
#  15  Product Name    12057 non-null  object
# ...

# %%
sns.catplot("Country","Sales",data=vertical_stack)

# %%
df_new_copy2=df_copy2[df_copy2.Country=="France"]

# %%
vertical_stack = pd.concat([vertical_stack,df_new_copy2], axis=0)

# %%
sns.catplot("Country","Sales",data=vertical_stack)

# %%
df_new_copy3=df_copy2[df_copy2.Country=="China"]

# %%
vertical_stack = pd.concat([vertical_stack, df_new_copy3], axis=0)

# %%
sns.catplot("Country","Sales",data=vertical_stack)

# %%
df_new_copy4=df_copy2[df_copy2.Country=="Australia"]

# %%
vertical_stack = pd.concat([vertical_stack,df_new_copy4], axis=0)

# %%
sns.catplot("Country","Sales",data=vertical_stack)

# %% [markdown]
# #df_copy1 =usa
# #df_new_copy1=germany
# #df_new_copy2=france
# #df_new_copy3=china
# #df_new_copy4=australia

# %%
sns.catplot("Country","Sales",data=df_copy1)

# %%
sns.catplot("Country","Sales",data=df_new_copy1)

# %%
sns.catplot("Country","Sales",data=df_new_copy2)

# %%
sns.catplot("Country","Sales",data=df_new_copy3)

# %%
sns.catplot("Country","Sales",data=df_new_copy4)
